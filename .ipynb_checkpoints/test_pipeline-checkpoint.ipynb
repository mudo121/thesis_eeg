# %% [markdown]
# # Notebok to test Pipelines

# %%
# Imports
import os, sys
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# to enable local imports
module_path = os.path.abspath(os.path.join('code'))
if module_path not in sys.path:
    sys.path.append(module_path)

from pipelines import filter_signal, pre_process_signal, feature_extraction
from utils import loadConfigFile
from plotFunctions import plot_magnitudeFreq_and_PSD

# %%
SUBJECT = 2 # Subject to use

# Import a subjectDict
from data import testSubjectDict as subjectDict

# Load the yaml config
yamlConfig = loadConfigFile(subjectDict[SUBJECT]["Device"])

# create a df
df = pd.read_csv(subjectDict[SUBJECT]["unlabeledCsvPath"])
# Out:
# Loading the config file for muse-lsl

# %%
# Filter Signal
df = filter_signal(df=df, config=yamlConfig)

# %%
df_series = pre_process_signal(df=df, config=yamlConfig)
# Out:
# Creating sliding windows...
# Deleting faulty data...
# Deleting Nan's...
# Normalizing data...

# %%
feature_df = feature_extraction(epochSeries=df_series, config=yamlConfig)
# Out:
# Frequenccy Bands: [(0.5, 4, 'Delta'), (4, 8, 'Theta'), (8, 12, 'Alpha'), (12, 30, 'Beta'), (30, 50, 'Gamma')]
# C:\Users\reiss\Anaconda3\envs\ml\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 1024 is greater than input length  = 512, using nperseg = 512
#   .format(nperseg, input_length))
# Creating bandpower, lower & upper envelope dictionary...
# Creating statistics bandpower dict...
# Creating a nice feature dataframe...

# %%
feature_df.head()
# Out:
#    channel_1_Delta_mean_bandpower_list  \
# 0                             0.242705
# 1                             0.250193
# 2                             0.275027
# 3                             0.244655
# 4                             0.162343
#
#    channel_1_Delta_mean_bandpower_lower_envelope_list  \
# 0                                           0.169580
# 1                                           0.157255
# 2                                           0.234020
# 3                                           0.186725
# 4                                           0.120044
#
#    channel_1_Delta_mean_bandpower_upper_envelope_list  \
# 0                                           0.318099
# 1                                           0.279050
# 2                                           0.301901
# 3                                           0.306194
# 4                                           0.247225
#
#    channel_1_Delta_std_dev_bandpower_list  \
# 0                                0.149809
# 1                                0.040168
# 2                                0.057431
# 3                                0.064758
# 4                                0.083328
#
#    channel_1_Delta_std_dev_bandpower_lower_envelope_list  \
# 0                                           0.179691
# 1                                           0.048664
# 2                                           0.042044
# 3                                           0.055763
# 4                                           0.041374
#
#    channel_1_Delta_std_dev_bandpower_upper_envelope_list  \
# 0                                           0.084017
# 1                                           0.020502
# 2                                           0.021296
# 3                                           0.045333
# 4                                           0.057329
#
#    channel_1_Theta_mean_bandpower_list  \
# 0                             0.225503
# 1                             0.219551
# 2                             0.209837
# 3                             0.251539
# 4                             0.165876
#
#    channel_1_Theta_mean_bandpower_lower_envelope_list  \
# 0                                           0.179094
# 1                                           0.190524
# 2                                           0.166950
# 3                                           0.158284
# 4                                           0.120026
#
#    channel_1_Theta_mean_bandpower_upper_envelope_list  \
# 0                                           0.261650
# 1                                           0.277611
# 2                                           0.237896
# 3                                           0.295505
# 4                                           0.228529
#
#    channel_1_Theta_std_dev_bandpower_list  ...  \
# 0                                0.059425  ...
# 1                                0.080856  ...
# 2                                0.063444  ...
# 3                                0.056171  ...
# 4                                0.045466  ...
#
#    channel_4_Beta_mean_bandpower_upper_envelope_list  \
# 0                                           0.179675
# 1                                           0.371695
# 2                                           0.311840
# 3                                           0.405422
# 4                                           0.308624
#
#    channel_4_Beta_std_dev_bandpower_list  \
# 0                               0.102213
# 1                               0.103230
# 2                               0.081233
# 3                               0.103512
# 4                               0.072775
#
#    channel_4_Beta_std_dev_bandpower_lower_envelope_list  \
# 0                                           0.031803
# 1                                           0.009566
# 2                                           0.063987
# 3                                           0.050432
# 4                                           0.026279
#
#    channel_4_Beta_std_dev_bandpower_upper_envelope_list  \
# 0                                           0.083175
# 1                                           0.023211
# 2                                           0.019155
# 3                                           0.022091
# 4                                           0.040836
#
#    channel_4_Gamma_mean_bandpower_list  \
# 0                             0.114578
# 1                             0.115024
# 2                             0.136147
# 3                             0.144758
# 4                             0.145719
#
#    channel_4_Gamma_mean_bandpower_lower_envelope_list  \
# 0                                           0.018796
# 1                                           0.074729
# 2                                           0.087796
# 3                                           0.112960
# 4                                           0.118857
#
#    channel_4_Gamma_mean_bandpower_upper_envelope_list  \
# 0                                           0.144444
# 1                                           0.153332
# 2                                           0.188834
# 3                                           0.202700
# 4                                           0.184833
#
#    channel_4_Gamma_std_dev_bandpower_list  \
# 0                                0.055263
# 1                                0.029655
# 2                                0.045610
# 3                                0.044237
# 4                                0.042595
#
#    channel_4_Gamma_std_dev_bandpower_lower_envelope_list  \
# 0                                           0.016417
# 1                                           0.028312
# 2                                           0.016325
# 3                                           0.041546
# 4                                           0.030084
#
#    channel_4_Gamma_std_dev_bandpower_upper_envelope_list
# 0                                           0.060209
# 1                                           0.012926
# 2                                           0.004857
# 3                                           0.006027
# 4                                           0.008306
#
# [5 rows x 120 columns]

# %%
def plot_feature(feature_df, featureName = None, frequencyBand = None, channel = None):
    '''
    This function plots feature according to the given parameters
    
    
    @param str featureName: mean_bandpower_list | mean_bandpower_lower_envelope | mean_bandpower_upper_envelope | std_dev_bandpower_lower_envelope | ...
    @param str frequencyBand: E.g. Alpha, Beta, Gamma
    @param str channel: 1, 2, 3, or None for all
    
    If one of the param is None then it doesn't get filtered
    
    '''
    if featureName != None:
        feature_df = feature_df.filter(like=featureName)
        
    if frequencyBand != None:
        feature_df = feature_df.filter(like=frequencyBand)
        
    if channel != None:
        feature_df = feature_df.filter(like=channel)
    
    plt.figure(figsize=(20,5))
    
    for column in feature_df:
        plt.plot(feature_df[column], label=column)
    plt.legend()


plot_feature(feature_df, featureName="mean_bandpower_list", frequencyBand="Delta")

# %%
for column in feature_df:
    print (column)
# Out:
# channel_1_Delta_mean_bandpower_list
# channel_1_Delta_mean_bandpower_lower_envelope_list
# channel_1_Delta_mean_bandpower_upper_envelope_list
# channel_1_Delta_std_dev_bandpower_list
# channel_1_Delta_std_dev_bandpower_lower_envelope_list
# channel_1_Delta_std_dev_bandpower_upper_envelope_list
# channel_1_Theta_mean_bandpower_list
# channel_1_Theta_mean_bandpower_lower_envelope_list
# channel_1_Theta_mean_bandpower_upper_envelope_list
# channel_1_Theta_std_dev_bandpower_list
# channel_1_Theta_std_dev_bandpower_lower_envelope_list
# channel_1_Theta_std_dev_bandpower_upper_envelope_list
# channel_1_Alpha_mean_bandpower_list
# channel_1_Alpha_mean_bandpower_lower_envelope_list
# channel_1_Alpha_mean_bandpower_upper_envelope_list
# channel_1_Alpha_std_dev_bandpower_list
# channel_1_Alpha_std_dev_bandpower_lower_envelope_list
# channel_1_Alpha_std_dev_bandpower_upper_envelope_list
# channel_1_Beta_mean_bandpower_list
# channel_1_Beta_mean_bandpower_lower_envelope_list
# channel_1_Beta_mean_bandpower_upper_envelope_list
# channel_1_Beta_std_dev_bandpower_list
# channel_1_Beta_std_dev_bandpower_lower_envelope_list
# channel_1_Beta_std_dev_bandpower_upper_envelope_list
# channel_1_Gamma_mean_bandpower_list
# channel_1_Gamma_mean_bandpower_lower_envelope_list
# channel_1_Gamma_mean_bandpower_upper_envelope_list
# channel_1_Gamma_std_dev_bandpower_list
# channel_1_Gamma_std_dev_bandpower_lower_envelope_list
# channel_1_Gamma_std_dev_bandpower_upper_envelope_list
# channel_2_Delta_mean_bandpower_list
# channel_2_Delta_mean_bandpower_lower_envelope_list
# channel_2_Delta_mean_bandpower_upper_envelope_list
# channel_2_Delta_std_dev_bandpower_list
# channel_2_Delta_std_dev_bandpower_lower_envelope_list
# channel_2_Delta_std_dev_bandpower_upper_envelope_list
# channel_2_Theta_mean_bandpower_list
# channel_2_Theta_mean_bandpower_lower_envelope_list
# channel_2_Theta_mean_bandpower_upper_envelope_list
# channel_2_Theta_std_dev_bandpower_list
# channel_2_Theta_std_dev_bandpower_lower_envelope_list
# channel_2_Theta_std_dev_bandpower_upper_envelope_list
# channel_2_Alpha_mean_bandpower_list
# channel_2_Alpha_mean_bandpower_lower_envelope_list
# channel_2_Alpha_mean_bandpower_upper_envelope_list
# channel_2_Alpha_std_dev_bandpower_list
# channel_2_Alpha_std_dev_bandpower_lower_envelope_list
# channel_2_Alpha_std_dev_bandpower_upper_envelope_list
# channel_2_Beta_mean_bandpower_list
# channel_2_Beta_mean_bandpower_lower_envelope_list
# channel_2_Beta_mean_bandpower_upper_envelope_list
# channel_2_Beta_std_dev_bandpower_list
# channel_2_Beta_std_dev_bandpower_lower_envelope_list
# channel_2_Beta_std_dev_bandpower_upper_envelope_list
# channel_2_Gamma_mean_bandpower_list
# channel_2_Gamma_mean_bandpower_lower_envelope_list
# channel_2_Gamma_mean_bandpower_upper_envelope_list
# channel_2_Gamma_std_dev_bandpower_list
# channel_2_Gamma_std_dev_bandpower_lower_envelope_list
# channel_2_Gamma_std_dev_bandpower_upper_envelope_list
# channel_3_Delta_mean_bandpower_list
# channel_3_Delta_mean_bandpower_lower_envelope_list
# channel_3_Delta_mean_bandpower_upper_envelope_list
# channel_3_Delta_std_dev_bandpower_list
# channel_3_Delta_std_dev_bandpower_lower_envelope_list
# channel_3_Delta_std_dev_bandpower_upper_envelope_list
# channel_3_Theta_mean_bandpower_list
# channel_3_Theta_mean_bandpower_lower_envelope_list
# channel_3_Theta_mean_bandpower_upper_envelope_list
# channel_3_Theta_std_dev_bandpower_list
# channel_3_Theta_std_dev_bandpower_lower_envelope_list
# channel_3_Theta_std_dev_bandpower_upper_envelope_list
# channel_3_Alpha_mean_bandpower_list
# channel_3_Alpha_mean_bandpower_lower_envelope_list
# channel_3_Alpha_mean_bandpower_upper_envelope_list
# channel_3_Alpha_std_dev_bandpower_list
# channel_3_Alpha_std_dev_bandpower_lower_envelope_list
# channel_3_Alpha_std_dev_bandpower_upper_envelope_list
# channel_3_Beta_mean_bandpower_list
# channel_3_Beta_mean_bandpower_lower_envelope_list
# channel_3_Beta_mean_bandpower_upper_envelope_list
# channel_3_Beta_std_dev_bandpower_list
# channel_3_Beta_std_dev_bandpower_lower_envelope_list
# channel_3_Beta_std_dev_bandpower_upper_envelope_list
# channel_3_Gamma_mean_bandpower_list
# channel_3_Gamma_mean_bandpower_lower_envelope_list
# channel_3_Gamma_mean_bandpower_upper_envelope_list
# channel_3_Gamma_std_dev_bandpower_list
# channel_3_Gamma_std_dev_bandpower_lower_envelope_list
# channel_3_Gamma_std_dev_bandpower_upper_envelope_list
# channel_4_Delta_mean_bandpower_list
# channel_4_Delta_mean_bandpower_lower_envelope_list
# channel_4_Delta_mean_bandpower_upper_envelope_list
# channel_4_Delta_std_dev_bandpower_list
# channel_4_Delta_std_dev_bandpower_lower_envelope_list
# channel_4_Delta_std_dev_bandpower_upper_envelope_list
# channel_4_Theta_mean_bandpower_list
# channel_4_Theta_mean_bandpower_lower_envelope_list
# channel_4_Theta_mean_bandpower_upper_envelope_list
# channel_4_Theta_std_dev_bandpower_list
# channel_4_Theta_std_dev_bandpower_lower_envelope_list
# channel_4_Theta_std_dev_bandpower_upper_envelope_list
# channel_4_Alpha_mean_bandpower_list
# channel_4_Alpha_mean_bandpower_lower_envelope_list
# channel_4_Alpha_mean_bandpower_upper_envelope_list
# channel_4_Alpha_std_dev_bandpower_list
# channel_4_Alpha_std_dev_bandpower_lower_envelope_list
# channel_4_Alpha_std_dev_bandpower_upper_envelope_list
# channel_4_Beta_mean_bandpower_list
# channel_4_Beta_mean_bandpower_lower_envelope_list
# channel_4_Beta_mean_bandpower_upper_envelope_list
# channel_4_Beta_std_dev_bandpower_list
# channel_4_Beta_std_dev_bandpower_lower_envelope_list
# channel_4_Beta_std_dev_bandpower_upper_envelope_list
# channel_4_Gamma_mean_bandpower_list
# channel_4_Gamma_mean_bandpower_lower_envelope_list
# channel_4_Gamma_mean_bandpower_upper_envelope_list
# channel_4_Gamma_std_dev_bandpower_list
# channel_4_Gamma_std_dev_bandpower_lower_envelope_list
# channel_4_Gamma_std_dev_bandpower_upper_envelope_list
