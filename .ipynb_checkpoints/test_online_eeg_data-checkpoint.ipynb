# %% [markdown]
# # Test Online EEG Data
# Data: https://figshare.com/articles/The_original_EEG_data_for_driver_fatigue_detection/5202739
#
# The Data is in .cnt and needs to be converted to .csv

# %%
# Imports
import os, sys
import pandas as pd
from datetime import datetime
import numpy as np

# to enable local imports
module_path = os.path.abspath(os.path.join('code'))
if module_path not in sys.path:
    sys.path.append(module_path)

from machine_learning_data_generation import generateFeatureDf, pre_process_signal, feature_extraction
from utils import loadConfigFile
from plotFunctions import plot_magnitudeFreq_and_PSD
from pipelines import filter_signal

# %% [markdown]
# ### Function to convert all the .cnt files to .csv - Does not need to be done again

# %%
from mne.io import read_raw_cnt

def convertAllCntToCsv(fileDir : str):
    ''' Convert all the .cnt files to .csv - Needs to be done only once'''
    # loop through the subjects
    print("Already done that..")
    return
    
    for i in range(1, 13):
        print("Converting Subject {}".format(i))
        rawCntNormal = read_raw_cnt(input_fname=os.path.join(fileDir,str(i),"Normal state.cnt"), preload=True, data_format='int32')
        df = rawCntNormal.to_data_frame()
        df.to_csv(os.path.join(fileDir,str(i),"Normal_state.csv"))
        
        rawCntFatigue = read_raw_cnt(input_fname=os.path.join(fileDir,str(i),"Fatigue state.cnt"), preload=True, data_format='int32')
        df = rawCntFatigue.to_data_frame()
        df.to_csv(os.path.join(fileDir,str(i),"Fatigue_state.csv"))
        
    print("Done")   

#convertAllCntToCsv("D:/Masterthesis/EEG_Data/eeg_data_online/")

# %%
#import mne
#mneRaw = mne.io.read_raw_cnt("D:/Masterthesis/EEG_Data/eeg_data_online/1/Normal state.cnt", data_format="int32", preload=True)
#mneRaw.info

# %% [markdown]
# ## Resample from 1000Hz to 256Hz

# %%
import scipy

def resampleAllFles(fileDir : str, newSampleRate=256, currentSamplingRate=1000):
    ''' Resample all orignal 1000hz eeg files to a given new sample rate'''
    # loop through the subjects
    
    print("Already Done!")
    return
    
    for i in range(1, 13):
        print("Resample Subject {} from {}Hz to {}Hz...".format(i, currentSamplingRate, newSampleRate))
        df_normal = pd.read_csv(os.path.join(fileDir,str(i),"Normal_state.csv"))
        del df_normal['Unnamed: 0']
        del df_normal['time']
        
        # here we can calculate the total amount of new samples with the new sampling rate
        sumSamples = len(df_normal.index)
        newSumSamples = int(sumSamples / (currentSamplingRate / newSampleRate))
        
        # now resample each column
        resampledDf = pd.DataFrame() # create a new df
        for column in df_normal:
            resampledDf[column] = scipy.signal.resample(df_normal[column], newSumSamples)
        
        # save to csv
        resampledDf.to_csv(os.path.join(fileDir,str(i),"Normal_state_{}hz.csv".format(newSampleRate)))
        
        
        # Do the same with the fatigue csv file
        df_fatigue = pd.read_csv(os.path.join(fileDir,str(i),"Fatigue_state.csv"))
        del df_fatigue['Unnamed: 0']
        del df_fatigue['time']
        
        # We don't have to calculate the sum of samples again, because it's the same
        
        # now resample each column
        resampledDf = pd.DataFrame() # create a new df
        for column in df_fatigue:
            resampledDf[column] = scipy.signal.resample(df_fatigue[column], newSumSamples)
        
        # save to csv
        resampledDf.to_csv(os.path.join(fileDir,str(i),"Fatigue_state_{}hz.csv".format(newSampleRate)))

    print("Done")   

#resampleAllFles("D:/Masterthesis/EEG_Data/eeg_data_online/")

# %% [markdown]
# ### Test the .csv file

# %%
df = pd.read_csv("D:/Masterthesis/EEG_Data/eeg_data_online/1/Normal_state_256hz.csv")
#del df['Unnamed: 0']
#del df['time']
df.head()
# Out:
#    Unnamed: 0          HEOL  HEOR           FP1           FP2          VEOU  \
# 0           0 -18243.758679   0.0 -16347.708653 -22227.379914 -12425.494246
# 1           1 -18582.995890   0.0 -16498.894479 -21835.446425 -12706.278297
# 2           2 -18486.418157   0.0 -16456.585766 -21946.025432 -12626.847584
# 3           3 -18549.398771   0.0 -16494.448288 -21886.737227 -12689.223841
# 4           4 -18507.959453   0.0 -16477.323258 -21926.699669 -12658.185456
#
#           VEOL           F7            F3            FZ  ...            P4  \
# 0  -996.945641 -9951.427774 -20989.572557 -22328.058492  ... -17963.101320
# 1 -1525.528044 -9548.088520 -20994.465019 -21925.610738  ... -16645.787683
# 2 -1380.125633 -9663.555267 -20988.342788 -22037.823075  ... -17015.177873
# 3 -1473.823896 -9603.906021 -20993.796526 -21973.047947  ... -16799.525590
# 4 -1415.281737 -9653.890477 -20993.400559 -22021.513038  ... -16955.987523
#
# ...

# %%
plot_magnitudeFreq_and_PSD(df.HEOL, samplingRate=256, signalName="FP2")

# %% [markdown]
# # Main

# %%
GENERATE_DATA = False
print("Generate data is '{}'".format(GENERATE_DATA))
# load config
MAIN_DIR = "D:/Masterthesis/thesis_eeg/generatedData"

TARGET_AWAKE = "awake"
TARGET_NON_AWAKE = "non_awake"
TARGET_UNLABELED = "unlabeled"


SUBJECT = 2 # Subject to use
from data import onlineEegDataDict as subjectDict
yamlConfig = loadConfigFile(subjectDict[SUBJECT]["Device"])


# ---- AWAKE DATA -----
epochSeries_awake, frequencyFeatureDf_awake = generateFeatureDf(csvFilePath="D:/Masterthesis/EEG_Data/eeg_data_online/1/Normal_state_256hz.csv",
                                                    starttime = pd.Timestamp(datetime.now()),
                                                    yamlConfig = yamlConfig,
                                                    label = TARGET_AWAKE,
                                                    generateData = GENERATE_DATA,
                                                    mainDir = MAIN_DIR)

# ---- FATIGUE DATA -----
epochSeries_fatigue, frequencyFeatureDf_fatigue = generateFeatureDf(csvFilePath="D:/Masterthesis/EEG_Data/eeg_data_online/1/Fatigue_state_256hz.csv",
                                                    starttime = pd.Timestamp(datetime.now()),
                                                    yamlConfig = yamlConfig,
                                                    label = TARGET_AWAKE,
                                                    generateData = GENERATE_DATA,
                                                    mainDir = MAIN_DIR)

print("Frequency Feature Df has {} Epochs and {} Features.".format(frequencyFeatureDf_awake.shape[0],
                                                                    frequencyFeatureDf_awake.shape[1]))
# Out:
# Generate data is 'False'
# Loading the config file for neuroscan
# Reading pickles files for awake data...
# Reading pickles files for awake data...
# Frequency Feature Df has 60 Epochs and 1200 Features.

# %%
from typing import List
from consts import DEVICES_NEUROSCAN
from machine_learning_data_generation import createDataAndTargetArray

TARGET_AWAKE = "awake"
TARGET_NON_AWAKE = "non_awake"
TARGET_UNLABELED = "unlabeled"

# importing copy module 
import copy 

def readDatasetFromDirectory(directory : str,
                             device : str,
                             generateData : bool, 
                             channelsToUse : List,
                             awakeFilename : str,
                             fatigueFilename : str,
                             maxPercentageNanValues : float) -> (np.ndarray, np.ndarray):
    
    # First load the yaml config for the device
    yamlConfig = loadConfigFile(device)
    
    dataArray = None
    targetArray = None
    
    for root, dirs, files in os.walk(directory):
        for subjectDir in dirs:
            print("Load Subject {} Data...".format(subjectDir))
            
            epochSeries_awake, frequencyFeatureDf_awake = generateFeatureDf(csvFilePath=os.path.join(root, subjectDir, awakeFilename),
                                                    starttime = pd.Timestamp(datetime.now()), # Todo Verbessern
                                                    yamlConfig = yamlConfig,
                                                    label = TARGET_AWAKE,
                                                    generateData = generateData,
                                                    mainDir = os.path.join(root, subjectDir))
                                                                            
            # ---- FATIGUE DATA -----
            epochSeries_fatigue, frequencyFeatureDf_fatigue = generateFeatureDf(csvFilePath=os.path.join(root, subjectDir, fatigueFilename),
                                                    starttime = pd.Timestamp(datetime.now()),
                                                    yamlConfig = yamlConfig,
                                                    label = TARGET_NON_AWAKE,
                                                    generateData = generateData,
                                                    mainDir = os.path.join(root, subjectDir))
                                                                            
            # Create Data and Target Arrays
            tempDataArray, tempTargetArray = createDataAndTargetArray(awakeDf = frequencyFeatureDf_awake, # normal
                                                 non_awakeDf = frequencyFeatureDf_fatigue, # fatigue
                                                 unlabeledDf = None,
                                                 channelsToUse = channelsToUse,
                                                 maxPercentageNanValues=5.0) # 0 leads to no data recrods at all
                                                                            
            # Add the temp arrays to the dataset
            # Use deep copy to not have any issues if the array gets replaced again
            '''
            if dataArray is None:
                dataArray = copy.deepcopy(tempDataArray)
            else:
                dataArray = np.concatenate([dataArray, tempDataArray], axis=0)
            
            if targetArray is None:
                targetArray = copy.deepcopy(tempDataArray)
            else:
                targetArray = np.concatenate([targetArray, tempTargetArray], axis=0)
            '''
            

    print ("Done creating a dataset from {}".format(directory))
    return (dataArray, targetArray)
                                                                            
                                                                        
    
myDir = "D:/Masterthesis/EEG_Data/eeg_data_online"

channelsToUse = ['channel_6_']

dataArray, targetArray = readDatasetFromDirectory(directory = myDir,
                                                    device = DEVICES_NEUROSCAN,
                                                    generateData = True, 
                                                    channelsToUse = channelsToUse,
                                                    awakeFilename = "Normal_state_256hz.csv",
                                                    fatigueFilename = "Fatigue_state_256hz.csv",
                                                    maxPercentageNanValues = 5.0)
# Out:
# Loading the config file for neuroscan
# Load Subject 1 Data...
# Generating awake driving feature df...
# Creating sliding windows...
# Deleting faulty data...
# Deleting Nan's...
# Normalizing data...
# Saving epoch series...
# Frequenccy Bands: [(0.5, 4, 'Delta'), (4, 8, 'Theta'), (8, 12, 'Alpha'), (12, 30, 'Beta'), (30, 50, 'Gamma')]
# Creating bandpower, lower & upper envelope dictionary...
# Creating statistics bandpower dict...
# Creating a nice feature dataframe...
# Saving frequency feature dataframe...
# Generating non_awake driving feature df...
# Creating sliding windows...
# Deleting faulty data...
# Deleting Nan's...
# Normalizing data...
# Saving epoch series...
# Frequenccy Bands: [(0.5, 4, 'Delta'), (4, 8, 'Theta'), (8, 12, 'Alpha'), (12, 30, 'Beta'), (30, 50, 'Gamma')]
# Creating bandpower, lower & upper envelope dictionary...
# Creating statistics bandpower dict...
# Creating a nice feature dataframe...
# Saving frequency feature dataframe...
# ...

# %%
from plotFunctions import plot_feature
plot_feature(feature_df=frequencyFeatureDf_awake, featureName="mean_bandpower_list", frequencyBand=None, channel="_5_")

# %%
from machine_learning_data_generation import createDataAndTargetArray

channelsToUse = ['channel_6_']

dataArray, targetArray = createDataAndTargetArray(awakeDf = frequencyFeatureDf_awake, # normal
                                                 non_awakeDf = frequencyFeatureDf_fatigue, # fatigue
                                                 unlabeledDf = None,
                                                 channelsToUse = channelsToUse,
                                                 maxPercentageNanValues=5.0) # 0 leads to no data recrods at all
# Out:
# Creating Data and Target Array...
# Using the channels: channel_6_,
# Using Features where the NaN percentage is equal or lower than: 5.0
# Awake DF Columns: Index(['channel_6_Delta_mean_bandpower_list',
#        'channel_6_Delta_std_dev_bandpower_list',
#        'channel_6_Theta_mean_bandpower_list',
#        'channel_6_Theta_std_dev_bandpower_list',
#        'channel_6_Alpha_mean_bandpower_list',
#        'channel_6_Alpha_std_dev_bandpower_list',
#        'channel_6_Beta_mean_bandpower_list',
#        'channel_6_Beta_std_dev_bandpower_list',
#        'channel_6_Gamma_mean_bandpower_list',
#        'channel_6_Gamma_std_dev_bandpower_list'],
#       dtype='object')
# Non-Awake DF Columns: Index(['channel_6_Delta_mean_bandpower_list',
#        'channel_6_Delta_std_dev_bandpower_list',
#        'channel_6_Theta_mean_bandpower_list',
#        'channel_6_Theta_std_dev_bandpower_list',
#        'channel_6_Alpha_mean_bandpower_list',
#        'channel_6_Alpha_std_dev_bandpower_list',
# ...

# %%
from utils import filterDfByColumns

len(filterDfByColumns(frequencyFeatureDf_awake, channelsToUse).columns)
# Out:
# 30

# %%
# Check which features contain faulty data
#from Measuring_Functions import faultyFeaturesNames
#faultyFeaturesNames(frequencyFeatureDf_awake, maxPercentageMissing=5.0)

# %%
#datasetDataArray = np.ndarray(shape=(0,10))

test = np.concatenate([dataArray, dataArray], axis=0)

# %%
test = np.concatenate([test, dataArray], axis=0)

# %%
type(copy.deepcopy(dataArray))
# Out:
# numpy.ndarray
